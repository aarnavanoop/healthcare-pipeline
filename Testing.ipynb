# %%
import pandas as pd

# %%
df = pd.read_csv('data/processed/synthetic_cleveland.csv')

# %%
df.head()
# Out:
#         Age  Sex  Resting Blood Pressure  Serum Cholestrol in md/dl  \
# 0  0.156221  1.0               -4.450751                   0.716184
# 1  1.310530  1.0                0.909156                  -0.596531
# 2  0.532398  0.0                0.475425                   0.359387
# 3 -0.381636  0.0               -0.898878                  -0.416468
# 4  0.937248  1.0               -0.131197                   0.672829
#
#    Fasting Blood Sugar > 120mg/dl  Max Heart Rate  Exercise Induced Angina  \
# 0                             0.0       -4.226146                      1.0
# 1                             0.0        0.594736                      1.0
# 2                             0.0       -0.667140                      1.0
# 3                             0.0        0.167687                      0.0
# 4                             1.0       -0.830882                      1.0
#
#    ST Depression Induced  Number of Major Vessels  Diagnosis of Heart Disease  \
# ...
